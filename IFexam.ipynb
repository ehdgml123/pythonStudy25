# %% [markdown]
# <a href="https://colab.research.google.com/github/ehdgml123/pythonStudy25/blob/master/IFexam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# if 문은 제어문 으로 참, 거짓을 판단하여 흐름을 조절함
# ex : 돈이 있으면 택시를 타고 가고, 돈이 없으면 걸어가라!!
#             True                          False

# if 문법 암기 :
# if 변수(참, 거짓) :
# 탭(띄어쓰기) 실행문 -> 참 일때 실행문
# 탭(띄어쓰기) 실핼문 -> 참 일때 실행문
# else : -> 거짓일떄 실행문
# 탭(띄어쓰기) 실핼문 -> 참 일때 실행문


money = True   # 돈이 있다
if money :   # 만약에 money 값 안에 True 이면 아래 들여쓰기 한곳을 실행한다.
    print("택시를 타고 갑니다.")   # True 일때 출력문
else:     # 위에 if 문에 False가 들어올때 아래 들여쓰기 한 곳 실행
    print("걸어가라")
print("학교에 도착합니다")
# Out:
# 택시를 타고 갑니다.
# 학교에 도착합니다

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
money = int(input("현재 얼마있나요??"))
#            input("프로프트") : 키보드로 입력받은 값을 문자열로 보관
#          int("4000") : 숫자로 된 문자를 숫자화 -> 4000
  # input -> 키보드 로 입력받는거
#print("현재 주머니에 %s 원 이 있네요"% money)
if money >= 3000 :
    print("택시를 타고갑니다")
else :
    print("걸어갑니다")
# Out:
# 현재 얼마있나요??1500
# 걸어갑니다

# %%
# 돈이 3000원 이상 있거나 카드가 있다면 택시를 타고 가고, 그렇지 않으면 걸어가라

money = 2000
card = True
if money >= 3000 or card :
    print("택시를 타고 가라")
else :
    print("마! 걸어가라")
# Out:
# 택시를 타고 가라

# %%
1 in [1,2,3]
# Out:
# True

# %%
1 not in [1,2,3]
# Out:
# False

# %%
'a' in ('a', 'b', 'c')
# Out:
# True

# %%
'j' not in 'python'
# Out:
# True

# %%
# 만약 주머니에 돈이 있으면 택시를 타고 가고, 없으면 걸어가라.

pocket = ['paper', 'cellphone', 'money']
if 'money' in pocket :
    print("택시 타야지")
else :
    print("마! 걸어가라!")
# Out:
# 택시 타야지

# %%
# pass => pocket 리스트 안에 money 문자열이 있기 때문에 if 문 다음 문장인 pass가 수행되고 아무런 결괏값도 보여 주지 않는다.
pocket = ['paper', 'cellphone', 'money']
if 'money' in pocket:
    pass
else :
    print("카드를 꺼내라")

# %% [markdown]
# 다양한 조건을 판단하는 elif

# %%
# 주머니에 돈이 있으면 택시를 타고 가고, 주머니에 돈은 없지만 카드가 있으면 택시를 타고 가고,
# 돈도 없고 카드도 없으면 걸어가라.

pocket = ['paper', 'cellphone']
card = True
if 'money' in pocket :
    print("택시를 타라")
else :
    if card:
        print("마 카드 있네 택시타라")
    else :
        print("마 아무것도 없네 걸어가라")
# Out:
# 마 카드 있네 택시타라

# %%
# elif는 이전 조건문이 거짓일 때 수행된다. if, elif, else를 모두 사용할 때 기본 구조는 다음과 같다.

pocket = ['paper', 'cellphone']
card = True
if 'money' in pocket:
    print("택시를 타라")
elif card :
       print("카드가 있으니 택시를 타라")
else :
     print("마! 걸어가라!")
# Out:
# 카드가 있으니 택시를 타라

# %% [markdown]
# if 문을 한 줄로 작성하기

# %%
if 'money' in pocket:
    pass
else:
    print("카드를 꺼내라")
# Out:
# 카드를 꺼내라

# %%
pocket = ['paper', 'money', 'cellphone']
if 'money' in pocket: pass
else: print("카드를 꺼내라")

# %% [markdown]
# 조건부 표현식

# %%
score = int(input("점수를 입력하세요"))

if score >= 50 :
    print("합격")
else :
    print("불학격")
# Out:
# 점수를 입력하세요10
# 불학격

# %%
score = int(input("점수를 입력하세요"))

if score >= 60 :
    print("합격")
elif score  == 55 :
    print("컷트라이 합격")
else :
    print("불합격")
# Out:
# 점수를 입력하세요54
# 불합격

# %%
money = 1500
coff = 3

if money >= 1500 :
    print("아메리카노 1잔 나왔습니다")
    print("현재 남은 돈 은 %s 원입니다." % (money - 1500))
    print ("아메리카노 %s 잔 남았습니다." % (coff - 1))
elif money == 1500 :
    print("아메리카도 1잔 나왔습니다.")
    print("현재 남은 돈 은 %s 원입니다." % (money - 1500))
    print ("아메리카노 %s 잔 남았습니다." % (coff - 1))
else :
    print("잔액이 부족합니다.")
# Out:
# 아메리카노 1잔 나왔습니다
# 현재 남은 돈 은 0 원입니다.
# 아메리카노 2 잔 남았습니다.
